# %%
# %pip install google-cloud-bigquery pandas pymongo db-dtypes

# %%
import pandas as pd
from google.cloud import bigquery
from pymongo import MongoClient
import orjson

# 데이터 프레임 생성
bq_client = bigquery.Client.from_service_account_json('../../teemo-415918-c7066e71ebbb.json')
bq_origin_table_id = "teemo-415918.match_dataset.match_test2"

# %%
# MongoDB에 연결
mg_client = MongoClient("mongodb://localhost:27017/")
mg_db = mg_client["loldb"]
collection = mg_db["riot_match"]

# %%
query = f"""
SELECT *
FROM `{bq_origin_table_id}`
"""

df = bq_client.query(query).to_dataframe()
df
# Out:
#                                                 summonerId  riotIdGameName  \
# 0           iW-lVRNDtnLzAJDBKHAEFbsH3EAJGi4FQWPJGIrKwnPe9g         주연이 아빠
# 1          3BJ6obglWMc91VqA_6yJm_CjMZ0NSuJecSaRoWGVQx9OP_g         Satsuki
# 2          CAxGHR9cqurLaL-KRTtNODYF1f9VyPsCU76YoQ3T3sBUZO4  betterlee O824
# 3          fUVhSPTkx_bms8eLbs1zClfHRLL-bFy_Iur2xbagOrowW8w          34살챌린저
# 4        XXIryfHdVkk3ASyeaDjvbKMnelmohA5AZb4_aRP9koQo3Y...           타다의 힘
# ...                                                    ...             ...
# 1320225    xsqebcjJdd3awteL7MKn35QRDoHnxURk-rwcWSrXXRI9F4E             도르왕
# 1320226  hKnWaF0pkI_ErcAJFaaFd753pvziXPP6vEoSgqvFNTRvKk...             닭발킥
# 1320227     zSmFdOS0CH4Uf81r0a5q27TiLZ3uXMzwdAAhFg1kc-a1Ng          동물만합니다
# 1320228   J4cFXFlEgMqDv8RtWlsJO45odCDF0CgCGYCfCkj7wCS-iySk       JDG Ruler
# 1320229    TtMwilLCJsAaBIC8UYC2wTfkxig2d9sOjkxREp7PCY6JRIg            속  죄
#
#         riotIdTagline  summonerLevel  teamId individualPosition     role  \
# 0                 KR1            434     100                TOP     SOLO
# 1                 KR1            366     200             JUNGLE     NONE
# 2                 KR1            196     100             BOTTOM    CARRY
# 3                박바로박            209     200            UTILITY  SUPPORT
# 4                 124             81     100                TOP     SOLO
# ...               ...            ...     ...                ...      ...
# 1320225           KR1            391     100                TOP      DUO
# 1320226           KR1            134     100                TOP     NONE
# 1320227           KR1            443     100             JUNGLE     NONE
# 1320228           이주현            210     100             BOTTOM    CARRY
# 1320229           KR2            348     100                TOP     NONE
#
#          championId  champLevel  item0  ...  epicMonsterSteals  \
# 0               516          16   1054  ...                  0
# 1               141          15   6692  ...                  0
# 2                81          15   3158  ...                  0
# 3                53          11   2010  ...                  0
# 4                19          17   3047  ...                  0
# ...             ...         ...    ...  ...                ...
# 1320225          58          14   1054  ...                  0
# 1320226         106          17   3089  ...                  0
# 1320227          33          14   6664  ...                  1
# 1320228         222          14   1038  ...                  0
# 1320229         777          17   6670  ...                  1
#
#          stealthWardsPlaced  abilityUses  defense  flex  offense  \
# 0                        12          172     5013  5008     5005
# 1                         1          349     5013  5008     5005
# 2                         3          586     5011  5008     5005
# 3                        33           73     5011  5010     5007
# 4                         7           95     5013  5008     5008
# ...                     ...          ...      ...   ...      ...
# 1320225                   5          146     5001  5008     5008
# 1320226                   8          186     5001  5008     5005
# 1320227                   4          223     5001  5008     5005
# 1320228                   5          215     5001  5008     5005
# 1320229                  10          517     5001  5008     5005
#
#                matchId   gameCreation  gameDuration    gameVersion
# 0        KR_6919049528  1706204261560          1836   14.2.556.584
# 1        KR_6919049528  1706204261560          1836   14.2.556.584
# 2        KR_6919290559  1706241216279          1843   14.2.556.584
# 3        KR_6919169121  1706224045043          1692   14.2.556.584
# 4        KR_6919165465  1706224516809          1721   14.2.556.584
# ...                ...            ...           ...            ...
# 1320225  KR_6997324009  1711114657001          1017  14.6.569.5139
# 1320226  KR_6998017865  1711160219319          1532  14.6.569.5139
# 1320227  KR_6998017865  1711160219319          1532  14.6.569.5139
# 1320228  KR_6998017865  1711160219319          1532  14.6.569.5139
# 1320229  KR_6997953396  1711154231157          1789  14.6.569.5139
#
# [1320230 rows x 62 columns]

# %%
# 데이터 프레임의 각 행을 MongoDB에 저장
records = orjson.loads(df.T.to_json()).values()
collection.insert_many(records)
